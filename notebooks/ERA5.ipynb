# %%
import xarray as xr
import numpy as np
import glob as glob

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
import cdsapi
c = cdsapi.Client()

# %%
ds = c.retrieve(
    'reanalysis-era5-single-levels-monthly-means',
    {
        'format': 'netcdf',
        'product_type': 'monthly_averaged_reanalysis',
        'time': '00:00',
        'month': [
            '06', '07', '08',
        ],
        'year': [
            '1979', '1980', '1981',
            '1982', '1983', '1984',
            '1985', '1986', '1987',
            '1988', '1989', '1990',
            '1991', '1992', '1993',
            '1994', '1995', '1996',
            '1997', '1998', '1999',
            '2000', '2001', '2002',
            '2003', '2004', '2005',
            '2006', '2007', '2008',
            '2009', '2010', '2011',
            '2012', '2013', '2014',
            '2015', '2016', '2017',
            '2018', '2019', '2020',
            '2021', '2022', '2023',
        ],
        'variable': [
            'volumetric_soil_water_layer_1', 'volumetric_soil_water_layer_2', 'volumetric_soil_water_layer_3',
            'volumetric_soil_water_layer_4',
        ],
    },
)
# Out:
# 2024-02-09 12:38:27,416 INFO Welcome to the CDS
# 2024-02-09 12:38:27,418 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels-monthly-means
# 2024-02-09 12:38:27,653 INFO Request is queued
# 2024-02-09 12:54:52,916 WARNING HTTP error: [500 Internal Server Error]. Attempt 1 of 500.
# 2024-02-09 12:54:52,918 WARNING Retrying in 120 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ds = c.retrieve(
#       2     'reanalysis-era5-single-levels-monthly-means',
#       3     {
#       4         'format': 'netcdf',
#       5         'product_type': 'monthly_averaged_reanalysis',
#       6         'time': '00:00',
#       7         'month': [
#       8             '06', '07', '08',
#       9         ],
#      10         'year': [
#      11             '1979', '1980', '1981',
#      12             '1982', '1983', '1984',
#      13             '1985', '1986', '1987',
#      14             '1988', '1989', '1990',
#      15             '1991', '1992', '1993',
#      16             '1994', '1995', '1996',
#      17             '1997', '1998', '1999',
#      18             '2000', '2001', '2002',
#      19             '2003', '2004', '2005',
#      20             '2006', '2007', '2008',
#      21             '2009', '2010', '2011',
#      22             '2012', '2013', '2014',
#      23             '2015', '2016', '2017',
#      24             '2018', '2019', '2020',
#      25             '2021', '2022', '2023',
#      26         ],
#      27         'variable': [
#      28             'volumetric_soil_water_layer_1', 'volumetric_soil_water_layer_2', 'volumetric_soil_water_layer_3',
#      29             'volumetric_soil_water_layer_4',
#      30         ],
#      31     },
#      32 )
#
# File ~/anaconda3/envs/ianpy37/lib/python3.10/site-packages/cdsapi/api.py:364, in Client.retrieve(self, name, request, target)
#     363 def retrieve(self, name, request, target=None):
# --> 364     result = self._api("%s/resources/%s" % (self.url, name), request, "POST")
#     365     if target is not None:
#     366         result.download(target)
#
# File ~/anaconda3/envs/ianpy37/lib/python3.10/site-packages/cdsapi/api.py:500, in Client._api(self, url, request, method)
#     497 task_url = "%s/tasks/%s" % (self.url, rid)
#     498 self.debug("GET %s", task_url)
# --> 500 result = self.robust(session.get)(
#     501     task_url, verify=self.verify, timeout=self.timeout
#     502 )
#     503 result.raise_for_status()
#     504 reply = result.json()
#
# File ~/anaconda3/envs/ianpy37/lib/python3.10/site-packages/cdsapi/api.py:638, in Client.robust.<locals>.wrapped(*args, **kwargs)
#     636 if tries < self.retry_max:
#     637     self.warning(f"Retrying in {self.sleep_max} seconds")
# --> 638     time.sleep(self.sleep_max)
#     639     self.info("Retrying now...")
#     640 else:
#
# KeyboardInterrupt:
